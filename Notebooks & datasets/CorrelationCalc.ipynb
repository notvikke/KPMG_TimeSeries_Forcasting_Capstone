# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Usuario\Desktop\CODE\IE CODE\3 TERM\CAPSTONE\IE KPMG_Demand Forecast dataset.csv")

# %%
df["Units"] = df["Units"]+1

# %%
import pandas as pd

# Assuming your dataframe is named 'df' and the date column is named 'date_column'

# Convert the 'date_column' to string type if it's not already
df['date_column'] = df['year-week'].astype(str)

# Filter the dataframe based on the condition
df = df[df['date_column'].str[:4] == '2022']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Pivot the data to create a matrix where each row represents a material and each column represents another material's sales
corr_matrix = df.pivot_table(index="year-week",columns='ID_material', values='Units', aggfunc='sum')

# %%
# Calculate the correlation coefficients
corr_matrix = corr_matrix.corr()

# %%
corr_matrix
# Out:
# ID_material  120004096  120009814  120009816  120010342  120010566  120010970  \
# ID_material
# 120004096     1.000000  -0.064003  -0.048583   0.065285  -0.160826   0.142613
# 120009814    -0.064003   1.000000   0.345903  -0.279850   0.029302  -0.117044
# 120009816    -0.048583   0.345903   1.000000  -0.011800   0.191379  -0.183771
# 120010342     0.065285  -0.279850  -0.011800   1.000000  -0.073965  -0.236795
# 120010566    -0.160826   0.029302   0.191379  -0.073965   1.000000  -0.139950
# 120010970     0.142613  -0.117044  -0.183771  -0.236795  -0.139950   1.000000
# 120011556     0.025724   0.412905   0.076901   0.055249   0.174166  -0.007981
# 120011782    -0.048881   0.282938   0.204478   0.175149   0.134056  -0.183250
# 120012154    -0.006361   0.137557   0.204329  -0.007771   0.565566  -0.105964
# 120012606    -0.017419   0.115098   0.252958   0.122193  -0.295562   0.213172
# 120014486     0.030911  -0.011067   0.176319  -0.158636  -0.187460  -0.010280
# ...

# %%
# Create a heatmap for the correlation matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Material Sales')
plt.xlabel('Material')
plt.ylabel('Material')
plt.show()
